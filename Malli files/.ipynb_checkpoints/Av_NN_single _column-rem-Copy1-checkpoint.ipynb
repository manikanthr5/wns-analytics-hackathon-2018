# %%
#library imports
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
#function and model imports
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm

from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import accuracy_score

# %%
import tensorflow as tf

# %%
def df_shuffle(inp):
    inp=shuffle(inp)
    inp=inp.reset_index(drop=True)
    return inp

# %%
train_data=pd.read_csv('../Data/train_LZdllcl.csv')
test_data=pd.read_csv('../Data/test_2umaH9m.csv')
print(train_data.shape)
print(test_data.shape)
#tr_data
# Out:
# (54808, 14)
# (23490, 13)

# %%
train_data=df_shuffle(train_data)

# %%
t=train_data.isnull().sum()
t[t>0]
# Out:
# education               2409
# previous_year_rating    4124
# dtype: int64

# %%
def process_categorical(train,test):    #use this after removing target variable
    fulldata=pd.concat([train,test],axis=0)
    fulldata=fulldata.fillna(-1)
    #fulldata=fulldata.drop('region',axis=1)
    fulldata['region']=fulldata['region'].apply(lambda x : int(x[7:]))
    trainend=len(train)
    onecoded=pd.get_dummies(fulldata)
    return (onecoded[:trainend],onecoded[trainend:])

# %%
#drop target variable for preprocessing
ytrainfull=train_data['is_promoted']
X_train=train_data.drop('is_promoted',axis=1)

# %%
xtrainfull,xtestproc=process_categorical(X_train,test_data)

# %%
#sample train data to test on itself
end = 40000 
xtrain = xtrainfull[:end]
ytrain = ytrainfull[:end]

xvalid = xtrainfull[end:54801] 
yvalid = ytrainfull[end:54801]
xvalid=xvalid.reset_index(drop=True)
yvalid=yvalid.reset_index(drop=True)

# %%
xtrain.shape
# Out:
# (40000, 27)

# %% [raw]
# X_train_std=xtrain
# X_test_std=xvalid
# X_sub_std=xtestproc

# %%
X_train_std=scale(xtrain)
X_test_std=scale(xvalid)
X_sub_std=scale(xtestproc)

# %%
Y_bin_train = pd.get_dummies(ytrain)
Y_bin_test = pd.get_dummies(yvalid)

# %%
# Parameters
learning_rate =0.005 #0.02
#num_steps = 500
batch_size = 128#128
#display_step = 100

# Network Parameters
n_hidden_1 = 20#36 # 1st layer number of neurons
n_hidden_2 = 10#24 # 2nd layer number of neurons
n_hidden_3 = 5#12
num_input = 26 # MNIST data input (img shape: 28*28)
num_classes = 2 # MNIST total classes (0-9 digits)


# tf Graph input
X = tf.placeholder("float", [None, num_input])
Y = tf.placeholder("float", [None, num_classes])

# %%
# Store layers weight & bias
inz = tf.contrib.layers.xavier_initializer()
weights = {
    'h1': tf.Variable(tf.random_normal([num_input, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, num_classes]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %%
# Create model
def neural_net(x):
    # Hidden fully connected layer with 256 neurons
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    # Hidden fully connected layer with 256 neurons
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    #layer_2 = tf.nn.dropout(layer_2, 0.9)
    # Output fully connected layer with a neuron for each class
    layer_3 = tf.add(tf.matmul(layer_2, weights['h3']), biases['b3'])
    layer_3 = tf.nn.relu(layer_3) 
    
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer

# %%
# Construct model
logits = neural_net(X)


class_weights = tf.constant([[1.0, 12.0]])
# Define loss and optimizer
#loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
#    logits=logits, labels=Y))
loss_op = tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(
    logits=logits, targets=Y,pos_weight=class_weights))


# your class weights
#class_weights = tf.constant([[1.0, 3.0]])
# deduce weights for batch samples based on their true label
#weights_imb = tf.reduce_sum(class_weights * Y, axis=1)
# compute your (unweighted) softmax cross entropy loss
#unweighted_losses = tf.nn.softmax_cross_entropy_with_logits(logits= logits,labels=Y)
# apply the weights, relying on broadcasting of the multiplication
#weighted_losses = unweighted_losses * weights_imb
# reduce the result to get your final loss
#loss_op = tf.reduce_mean(weighted_losses)





optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
pred_tf=tf.argmax(logits, 1)

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %% [raw]
# # Start training
#
# no_iterations = int(end/batch_size)-2
# print(no_iterations)
#
# with tf.Session() as sess:
#
#     # Run the initializer
#     sess.run(init)
#
#     for step in range(1, 30):
#         for no_batch in range(0,no_iterations):
#
#             batch_x = X_train_std[(no_batch*batch_size) :((no_batch+1)*batch_size) ]
#             batch_y = Y_bin_train[(no_batch*batch_size) :((no_batch+1)*batch_size) ]
#             # Run optimization op (backprop)
#             sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
#             #if step % display_step == 0 or step == 1:
#                 # Calculate batch loss and accuracy
#         loss, acc = sess.run([loss_op, accuracy], feed_dict={X: X_train_std,Y: Y_bin_train})
#         print("Step " + str(step) + ", Minibatch Loss= " + \
#                       "{:.4f}".format(loss) + ", Training Accuracy= " + \
#                       "{:.3f}".format(acc))
#         print("Testing Accuracy:", \
#         sess.run(accuracy, feed_dict={X: X_test_std,
#                                       Y: Y_bin_test}))
#     print("Optimization Finished!")
#
#     # Calculate accuracy for MNIST test images
#     print("Testing Accuracy:", \
#         sess.run(accuracy, feed_dict={X: X_test_std,
#                                       Y: Y_bin_test}))
#     test_pred= sess.run(pred_tf, feed_dict={X: X_test_std,Y: Y_bin_test})
#     tr_pred= sess.run(pred_tf, feed_dict={X: X_train_std,Y: Y_bin_test})
#     sub_pred= sess.run(pred_tf, feed_dict={X: X_sub_std})

# %%
# Start training

no_iterations = int(end/batch_size)-2

all_metrics=[]
for sel_col in range(0,len(xtrain.columns)):


    col_metrics=[]
    #col_mask=[sel_col,sel_col]
    col_mask =list(range(0,len(xtrain.columns)))
    col_mask.remove(sel_col)
    
    
    X_train_sel=X_train_std[:,col_mask]
    X_test_sel=X_test_std[:,col_mask]

    with tf.Session() as sess:

        # Run the initializer
        sess.run(init)

        for step in range(1, 25):
            for no_batch in range(0,no_iterations):

                batch_x = X_train_sel[(no_batch*batch_size) :((no_batch+1)*batch_size) ]
                batch_y = Y_bin_train[(no_batch*batch_size) :((no_batch+1)*batch_size) ]
                # Run optimization op (backprop)
                sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
                #if step % display_step == 0 or step == 1:
                    # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: X_train_sel,Y: Y_bin_train})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                          "{:.4f}".format(loss) + ", Training Accuracy= " + \
                          "{:.3f}".format(acc))
            print("Testing Accuracy:", \
            sess.run(accuracy, feed_dict={X: X_test_sel,
                                          Y: Y_bin_test}))
        print("Optimization Finished!")

        # Calculate accuracy for MNIST test images
        print("Testing Accuracy:", \
            sess.run(accuracy, feed_dict={X: X_test_sel,
                                          Y: Y_bin_test}))
        test_pred= sess.run(pred_tf, feed_dict={X: X_test_sel,Y: Y_bin_test})
        tr_pred= sess.run(pred_tf, feed_dict={X: X_train_sel,Y: Y_bin_train})
        precision, recall, fscore, support = score(yvalid, test_pred)
        tac=accuracy_score(yvalid, test_pred)
        #print("iter "+str(sel_col))
        #print('precision: {}'.format(precision))
        #print('recall: {}'.format(recall))
        #print('fscore: {}'.format(fscore))
        #print('support: {}'.format(support))
        col_name = xtrain.columns[sel_col]
        col_metrics = [col_name] +[tac] + list(recall) + list(precision)+list(fscore)
        all_metrics.append(col_metrics)
        #all_metrics.append([0,0])
# Out:
# Step 1, Minibatch Loss= 0.8644, Training Accuracy= 0.818
# Testing Accuracy: 0.8105533
# Step 2, Minibatch Loss= 0.6366, Training Accuracy= 0.888
# Testing Accuracy: 0.8801432
# Step 3, Minibatch Loss= 0.5771, Training Accuracy= 0.902
# Testing Accuracy: 0.892237
# Step 4, Minibatch Loss= 0.5371, Training Accuracy= 0.909
# Testing Accuracy: 0.8989257
# Step 5, Minibatch Loss= 0.5062, Training Accuracy= 0.911
# Testing Accuracy: 0.9012905
# Step 6, Minibatch Loss= 0.4820, Training Accuracy= 0.913
# Testing Accuracy: 0.9028444
# Step 7, Minibatch Loss= 0.4658, Training Accuracy= 0.915
# Testing Accuracy: 0.90473616
# Step 8, Minibatch Loss= 0.4539, Training Accuracy= 0.916
# Testing Accuracy: 0.9056145
# Step 9, Minibatch Loss= 0.4448, Training Accuracy= 0.920
# Testing Accuracy: 0.9091953
# Step 10, Minibatch Loss= 0.4381, Training Accuracy= 0.924
# Testing Accuracy: 0.914803
# Step 11, Minibatch Loss= 0.4337, Training Accuracy= 0.929
# Testing Accuracy: 0.91885686
# Step 12, Minibatch Loss= 0.4310, Training Accuracy= 0.930
# Testing Accuracy: 0.920073
# Step 13, Minibatch Loss= 0.4277, Training Accuracy= 0.930
# Testing Accuracy: 0.918992
# Step 14, Minibatch Loss= 0.4251, Training Accuracy= 0.929
# Testing Accuracy: 0.9190595
# Step 15, Minibatch Loss= 0.4224, Training Accuracy= 0.925
# Testing Accuracy: 0.914803
# Step 16, Minibatch Loss= 0.4201, Training Accuracy= 0.925
# Testing Accuracy: 0.91520846
# Step 17, Minibatch Loss= 0.4187, Training Accuracy= 0.926
# Testing Accuracy: 0.91703266
# Step 18, Minibatch Loss= 0.4172, Training Accuracy= 0.924
# Testing Accuracy: 0.91257346
# Step 19, Minibatch Loss= 0.4166, Training Accuracy= 0.923
# Testing Accuracy: 0.9127762
# Step 20, Minibatch Loss= 0.4151, Training Accuracy= 0.925
# Testing Accuracy: 0.91520846
# Step 21, Minibatch Loss= 0.4125, Training Accuracy= 0.926
# Testing Accuracy: 0.9154111
# Step 22, Minibatch Loss= 0.4135, Training Accuracy= 0.930
# Testing Accuracy: 0.9189244
# Step 23, Minibatch Loss= 0.4123, Training Accuracy= 0.928
# Testing Accuracy: 0.9176407
# Step 24, Minibatch Loss= 0.4133, Training Accuracy= 0.932
# Testing Accuracy: 0.9214918
# Optimization Finished!
# Testing Accuracy: 0.9214918
# Step 1, Minibatch Loss= 0.9743, Training Accuracy= 0.715
# Testing Accuracy: 0.71116817
# Step 2, Minibatch Loss= 0.6953, Training Accuracy= 0.740
# Testing Accuracy: 0.7355584
# Step 3, Minibatch Loss= 0.6087, Training Accuracy= 0.744
# Testing Accuracy: 0.73900414
# Step 4, Minibatch Loss= 0.5703, Training Accuracy= 0.747
# Testing Accuracy: 0.7411661
# Step 5, Minibatch Loss= 0.5452, Training Accuracy= 0.914
# Testing Accuracy: 0.9092629
# Step 6, Minibatch Loss= 0.5302, Training Accuracy= 0.915
# Testing Accuracy: 0.9091278
# Step 7, Minibatch Loss= 0.5195, Training Accuracy= 0.915
# Testing Accuracy: 0.90946555
# Step 8, Minibatch Loss= 0.5125, Training Accuracy= 0.916
# Testing Accuracy: 0.9100061
# Step 9, Minibatch Loss= 0.5061, Training Accuracy= 0.916
# Testing Accuracy: 0.9104115
# Step 10, Minibatch Loss= 0.5046, Training Accuracy= 0.916
# Testing Accuracy: 0.9106817
# Step 11, Minibatch Loss= 0.4987, Training Accuracy= 0.918
# Testing Accuracy: 0.9117627
# Step 12, Minibatch Loss= 0.4825, Training Accuracy= 0.923
# Testing Accuracy: 0.91514087
# Step 13, Minibatch Loss= 0.4529, Training Accuracy= 0.933
# Testing Accuracy: 0.92716706
# Step 14, Minibatch Loss= 0.4482, Training Accuracy= 0.935
# Testing Accuracy: 0.9304101
# Step 15, Minibatch Loss= 0.4340, Training Accuracy= 0.937
# Testing Accuracy: 0.9318289
# Step 16, Minibatch Loss= 0.4308, Training Accuracy= 0.939
# Testing Accuracy: 0.9336531
# Step 17, Minibatch Loss= 0.4238, Training Accuracy= 0.940
# Testing Accuracy: 0.93399096
# Step 18, Minibatch Loss= 0.4229, Training Accuracy= 0.940
# Testing Accuracy: 0.9341261
# Step 19, Minibatch Loss= 0.4210, Training Accuracy= 0.940
# Testing Accuracy: 0.93385583
# Step 20, Minibatch Loss= 0.4193, Training Accuracy= 0.941
# Testing Accuracy: 0.9348693
# Step 21, Minibatch Loss= 0.4191, Training Accuracy= 0.942
# Testing Accuracy: 0.9348017
# Step 22, Minibatch Loss= 0.4181, Training Accuracy= 0.942
# Testing Accuracy: 0.93459904
# Step 23, Minibatch Loss= 0.4124, Training Accuracy= 0.942
# Testing Accuracy: 0.93453145
# Step 24, Minibatch Loss= 0.4147, Training Accuracy= 0.942
# Testing Accuracy: 0.9341936
# Optimization Finished!
# Testing Accuracy: 0.9341936
# Step 1, Minibatch Loss= 0.8663, Training Accuracy= 0.903
# Testing Accuracy: 0.9004797
# Step 2, Minibatch Loss= 0.7848, Training Accuracy= 0.914
# Testing Accuracy: 0.9088575
# Step 3, Minibatch Loss= 0.7343, Training Accuracy= 0.918
# Testing Accuracy: 0.9127086
# Step 4, Minibatch Loss= 0.6648, Training Accuracy= 0.920
# Testing Accuracy: 0.91568136
# Step 5, Minibatch Loss= 0.5969, Training Accuracy= 0.906
# Testing Accuracy: 0.90034455
# Step 6, Minibatch Loss= 0.5429, Training Accuracy= 0.902
# Testing Accuracy: 0.8989933
# Step 7, Minibatch Loss= 0.5044, Training Accuracy= 0.906
# Testing Accuracy: 0.9018985
# Step 8, Minibatch Loss= 0.4773, Training Accuracy= 0.909
# Testing Accuracy: 0.9036552
# Step 9, Minibatch Loss= 0.4595, Training Accuracy= 0.913
# Testing Accuracy: 0.90656036
# Step 10, Minibatch Loss= 0.4485, Training Accuracy= 0.916
# Testing Accuracy: 0.9111546
# Step 11, Minibatch Loss= 0.4418, Training Accuracy= 0.919
# Testing Accuracy: 0.9129788
# Step 12, Minibatch Loss= 0.4359, Training Accuracy= 0.923
# Testing Accuracy: 0.916357
# Step 13, Minibatch Loss= 0.4308, Training Accuracy= 0.924
# Testing Accuracy: 0.9164246
# Step 14, Minibatch Loss= 0.4275, Training Accuracy= 0.926
# Testing Accuracy: 0.91791093
# Step 15, Minibatch Loss= 0.4230, Training Accuracy= 0.927
# Testing Accuracy: 0.9183839
# Step 16, Minibatch Loss= 0.4210, Training Accuracy= 0.927
# Testing Accuracy: 0.91757315
# Step 17, Minibatch Loss= 0.4175, Training Accuracy= 0.927
# Testing Accuracy: 0.9176407
# Step 18, Minibatch Loss= 0.4154, Training Accuracy= 0.928
# Testing Accuracy: 0.91865414
# Step 19, Minibatch Loss= 0.4130, Training Accuracy= 0.928
# Testing Accuracy: 0.9189244
# Step 20, Minibatch Loss= 0.4115, Training Accuracy= 0.928
# Testing Accuracy: 0.91939735
# Step 21, Minibatch Loss= 0.4100, Training Accuracy= 0.929
# Testing Accuracy: 0.91872174
# Step 22, Minibatch Loss= 0.4097, Training Accuracy= 0.929
# Testing Accuracy: 0.9196
# Step 23, Minibatch Loss= 0.4078, Training Accuracy= 0.929
# Testing Accuracy: 0.9182488
# Step 24, Minibatch Loss= 0.4068, Training Accuracy= 0.929
# Testing Accuracy: 0.9183163
# Optimization Finished!
# Testing Accuracy: 0.9183163
# Step 1, Minibatch Loss= 0.9268, Training Accuracy= 0.894
# Testing Accuracy: 0.89014256
# Step 2, Minibatch Loss= 0.7499, Training Accuracy= 0.907
# Testing Accuracy: 0.9020336
# Step 3, Minibatch Loss= 0.6540, Training Accuracy= 0.898
# Testing Accuracy: 0.8908858
# Step 4, Minibatch Loss= 0.5851, Training Accuracy= 0.900
# Testing Accuracy: 0.8939937
# Step 5, Minibatch Loss= 0.5369, Training Accuracy= 0.909
# Testing Accuracy: 0.9026417
# Step 6, Minibatch Loss= 0.5097, Training Accuracy= 0.913
# Testing Accuracy: 0.90824944
# Step 7, Minibatch Loss= 0.4871, Training Accuracy= 0.917
# Testing Accuracy: 0.9123708
# Step 8, Minibatch Loss= 0.4746, Training Accuracy= 0.917
# Testing Accuracy: 0.91061413
# Step 9, Minibatch Loss= 0.4643, Training Accuracy= 0.923
# Testing Accuracy: 0.9158165
# Step 10, Minibatch Loss= 0.4527, Training Accuracy= 0.927
# Testing Accuracy: 0.9203432
# Step 11, Minibatch Loss= 0.4438, Training Accuracy= 0.928
# Testing Accuracy: 0.9202756
# Step 12, Minibatch Loss= 0.4380, Training Accuracy= 0.931
# Testing Accuracy: 0.9227755
# Step 13, Minibatch Loss= 0.4352, Training Accuracy= 0.931
# Testing Accuracy: 0.9231133
# Step 14, Minibatch Loss= 0.4311, Training Accuracy= 0.933
# Testing Accuracy: 0.9256131
# Step 15, Minibatch Loss= 0.4289, Training Accuracy= 0.931
# Testing Accuracy: 0.9250051
# Step 16, Minibatch Loss= 0.4260, Training Accuracy= 0.933
# Testing Accuracy: 0.9252753
# Step 17, Minibatch Loss= 0.4264, Training Accuracy= 0.932
# Testing Accuracy: 0.9264239
# Step 18, Minibatch Loss= 0.4215, Training Accuracy= 0.933
# Testing Accuracy: 0.92784274
# Step 19, Minibatch Loss= 0.4189, Training Accuracy= 0.933
# Testing Accuracy: 0.9263563
# Step 20, Minibatch Loss= 0.4189, Training Accuracy= 0.935
# Testing Accuracy: 0.92973447
# Step 21, Minibatch Loss= 0.4168, Training Accuracy= 0.934
# Testing Accuracy: 0.9264239
# Step 22, Minibatch Loss= 0.4156, Training Accuracy= 0.933
# Testing Accuracy: 0.9251402
# Step 23, Minibatch Loss= 0.4208, Training Accuracy= 0.934
# Testing Accuracy: 0.92649144
# Step 24, Minibatch Loss= 0.4110, Training Accuracy= 0.931
# Testing Accuracy: 0.92284304
# Optimization Finished!
# Testing Accuracy: 0.92284304
# Step 1, Minibatch Loss= 0.8014, Training Accuracy= 0.913
# Testing Accuracy: 0.9085873
# Step 2, Minibatch Loss= 0.7666, Training Accuracy= 0.914
# Testing Accuracy: 0.9085873
# Step 3, Minibatch Loss= 0.7402, Training Accuracy= 0.914
# Testing Accuracy: 0.90892506
# Step 4, Minibatch Loss= 0.6844, Training Accuracy= 0.914
# Testing Accuracy: 0.9091953
# Step 5, Minibatch Loss= 0.6192, Training Accuracy= 0.915
# Testing Accuracy: 0.9098034
# Step 6, Minibatch Loss= 0.5726, Training Accuracy= 0.915
# Testing Accuracy: 0.90953314
# Step 7, Minibatch Loss= 0.5471, Training Accuracy= 0.914
# Testing Accuracy: 0.9081143
# Step 8, Minibatch Loss= 0.5272, Training Accuracy= 0.913
# Testing Accuracy: 0.90845215
# Step 9, Minibatch Loss= 0.5095, Training Accuracy= 0.918
# Testing Accuracy: 0.9132491
# Step 10, Minibatch Loss= 0.4827, Training Accuracy= 0.924
# Testing Accuracy: 0.91865414
# Step 11, Minibatch Loss= 0.4655, Training Accuracy= 0.931
# Testing Accuracy: 0.92291063
# Step 12, Minibatch Loss= 0.4518, Training Accuracy= 0.932
# Testing Accuracy: 0.924397
# Step 13, Minibatch Loss= 0.4430, Training Accuracy= 0.935
# Testing Accuracy: 0.9281805
# Step 14, Minibatch Loss= 0.4405, Training Accuracy= 0.937
# Testing Accuracy: 0.9311533
# Step 15, Minibatch Loss= 0.4357, Training Accuracy= 0.938
# Testing Accuracy: 0.93142354
# Step 16, Minibatch Loss= 0.4317, Training Accuracy= 0.938
# Testing Accuracy: 0.9305452
# Step 17, Minibatch Loss= 0.4292, Training Accuracy= 0.938
# Testing Accuracy: 0.93263966
# Step 18, Minibatch Loss= 0.4284, Training Accuracy= 0.939
# Testing Accuracy: 0.93277484
# Step 19, Minibatch Loss= 0.4275, Training Accuracy= 0.939
# Testing Accuracy: 0.93399096
# Step 20, Minibatch Loss= 0.4241, Training Accuracy= 0.941
# Testing Accuracy: 0.9343963
# Step 21, Minibatch Loss= 0.4233, Training Accuracy= 0.939
# Testing Accuracy: 0.9341936
# Step 22, Minibatch Loss= 0.4228, Training Accuracy= 0.941
# Testing Accuracy: 0.93513954
# Step 23, Minibatch Loss= 0.4223, Training Accuracy= 0.940
# Testing Accuracy: 0.93473417
# Step 24, Minibatch Loss= 0.4256, Training Accuracy= 0.940
# Testing Accuracy: 0.9348693
# Optimization Finished!
# Testing Accuracy: 0.9348693
# Step 1, Minibatch Loss= 0.8077, Training Accuracy= 0.916
# Testing Accuracy: 0.91149247
# Step 2, Minibatch Loss= 0.7771, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 3, Minibatch Loss= 0.6810, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 4, Minibatch Loss= 0.5873, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 5, Minibatch Loss= 0.5541, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 6, Minibatch Loss= 0.5343, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 7, Minibatch Loss= 0.5222, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 8, Minibatch Loss= 0.5143, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 9, Minibatch Loss= 0.5102, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 10, Minibatch Loss= 0.5085, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 11, Minibatch Loss= 0.5072, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 12, Minibatch Loss= 0.5045, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 13, Minibatch Loss= 0.5022, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 14, Minibatch Loss= 0.5023, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 15, Minibatch Loss= 0.4998, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 16, Minibatch Loss= 0.4967, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 17, Minibatch Loss= 0.4957, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 18, Minibatch Loss= 0.4967, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 19, Minibatch Loss= 0.4954, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 20, Minibatch Loss= 0.4933, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 21, Minibatch Loss= 0.4907, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 22, Minibatch Loss= 0.4921, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 23, Minibatch Loss= 0.4919, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 24, Minibatch Loss= 0.4898, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Optimization Finished!
# Testing Accuracy: 0.9116276
# /home/mallik/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Step 1, Minibatch Loss= 0.8472, Training Accuracy= 0.878
# Testing Accuracy: 0.87190056
# Step 2, Minibatch Loss= 0.7939, Training Accuracy= 0.909
# Testing Accuracy: 0.90399295
# Step 3, Minibatch Loss= 0.7637, Training Accuracy= 0.914
# Testing Accuracy: 0.9087224
# Step 4, Minibatch Loss= 0.7392, Training Accuracy= 0.915
# Testing Accuracy: 0.9099385
# Step 5, Minibatch Loss= 0.7137, Training Accuracy= 0.916
# Testing Accuracy: 0.9118303
# Step 6, Minibatch Loss= 0.6969, Training Accuracy= 0.917
# Testing Accuracy: 0.9123708
# Step 7, Minibatch Loss= 0.6770, Training Accuracy= 0.917
# Testing Accuracy: 0.9096007
# Step 8, Minibatch Loss= 0.6638, Training Accuracy= 0.921
# Testing Accuracy: 0.9141274
# Step 9, Minibatch Loss= 0.6513, Training Accuracy= 0.924
# Testing Accuracy: 0.9158165
# Step 10, Minibatch Loss= 0.6436, Training Accuracy= 0.925
# Testing Accuracy: 0.9178434
# Step 11, Minibatch Loss= 0.6317, Training Accuracy= 0.924
# Testing Accuracy: 0.9147355
# Step 12, Minibatch Loss= 0.6233, Training Accuracy= 0.927
# Testing Accuracy: 0.9179785
# Step 13, Minibatch Loss= 0.6136, Training Accuracy= 0.927
# Testing Accuracy: 0.9181812
# Step 14, Minibatch Loss= 0.6069, Training Accuracy= 0.931
# Testing Accuracy: 0.9220323
# Step 15, Minibatch Loss= 0.6043, Training Accuracy= 0.930
# Testing Accuracy: 0.9200054
# Step 16, Minibatch Loss= 0.6002, Training Accuracy= 0.931
# Testing Accuracy: 0.9214242
# Step 17, Minibatch Loss= 0.5959, Training Accuracy= 0.930
# Testing Accuracy: 0.9220323
# Step 18, Minibatch Loss= 0.5924, Training Accuracy= 0.931
# Testing Accuracy: 0.92250526
# Step 19, Minibatch Loss= 0.5899, Training Accuracy= 0.931
# Testing Accuracy: 0.9218296
# Step 20, Minibatch Loss= 0.5861, Training Accuracy= 0.932
# Testing Accuracy: 0.9225728
# Step 21, Minibatch Loss= 0.5830, Training Accuracy= 0.934
# Testing Accuracy: 0.92419434
# Step 22, Minibatch Loss= 0.5787, Training Accuracy= 0.932
# Testing Accuracy: 0.9236538
# Step 23, Minibatch Loss= 0.5766, Training Accuracy= 0.935
# Testing Accuracy: 0.9263563
# Step 24, Minibatch Loss= 0.5746, Training Accuracy= 0.933
# Testing Accuracy: 0.92473483
# Optimization Finished!
# Testing Accuracy: 0.92473483
# Step 1, Minibatch Loss= 0.8555, Training Accuracy= 0.913
# Testing Accuracy: 0.90824944
# Step 2, Minibatch Loss= 0.8151, Training Accuracy= 0.916
# Testing Accuracy: 0.9110195
# Step 3, Minibatch Loss= 0.8104, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 4, Minibatch Loss= 0.8096, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 5, Minibatch Loss= 0.8095, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 6, Minibatch Loss= 0.8084, Training Accuracy= 0.916
# Testing Accuracy: 0.9110871
# Step 7, Minibatch Loss= 0.8070, Training Accuracy= 0.916
# Testing Accuracy: 0.91135734
# Step 8, Minibatch Loss= 0.7995, Training Accuracy= 0.918
# Testing Accuracy: 0.91318154
# Step 9, Minibatch Loss= 0.7918, Training Accuracy= 0.919
# Testing Accuracy: 0.91439766
# Step 10, Minibatch Loss= 0.7683, Training Accuracy= 0.923
# Testing Accuracy: 0.9181812
# Step 11, Minibatch Loss= 0.7338, Training Accuracy= 0.928
# Testing Accuracy: 0.9220323
# Step 12, Minibatch Loss= 0.7029, Training Accuracy= 0.934
# Testing Accuracy: 0.9268293
# Step 13, Minibatch Loss= 0.6809, Training Accuracy= 0.936
# Testing Accuracy: 0.92791027
# Step 14, Minibatch Loss= 0.6683, Training Accuracy= 0.936
# Testing Accuracy: 0.92959934
# Step 15, Minibatch Loss= 0.6564, Training Accuracy= 0.937
# Testing Accuracy: 0.9311533
# Step 16, Minibatch Loss= 0.6449, Training Accuracy= 0.931
# Testing Accuracy: 0.9231809
# Step 17, Minibatch Loss= 0.6094, Training Accuracy= 0.920
# Testing Accuracy: 0.914803
# Step 18, Minibatch Loss= 0.5344, Training Accuracy= 0.927
# Testing Accuracy: 0.91878927
# Step 19, Minibatch Loss= 0.4880, Training Accuracy= 0.930
# Testing Accuracy: 0.9218972
# Step 20, Minibatch Loss= 0.4697, Training Accuracy= 0.937
# Testing Accuracy: 0.92905885
# Step 21, Minibatch Loss= 0.4526, Training Accuracy= 0.938
# Testing Accuracy: 0.93155867
# Step 22, Minibatch Loss= 0.4460, Training Accuracy= 0.939
# Testing Accuracy: 0.9318965
# Step 23, Minibatch Loss= 0.4404, Training Accuracy= 0.938
# Testing Accuracy: 0.93142354
# Step 24, Minibatch Loss= 0.4370, Training Accuracy= 0.938
# Testing Accuracy: 0.932437
# Optimization Finished!
# Testing Accuracy: 0.932437
# Step 1, Minibatch Loss= 0.8238, Training Accuracy= 0.909
# Testing Accuracy: 0.90406054
# Step 2, Minibatch Loss= 0.7813, Training Accuracy= 0.914
# Testing Accuracy: 0.9085197
# Step 3, Minibatch Loss= 0.7402, Training Accuracy= 0.907
# Testing Accuracy: 0.9021012
# Step 4, Minibatch Loss= 0.7134, Training Accuracy= 0.891
# Testing Accuracy: 0.88723737
# Step 5, Minibatch Loss= 0.6978, Training Accuracy= 0.884
# Testing Accuracy: 0.88102156
# Step 6, Minibatch Loss= 0.6885, Training Accuracy= 0.888
# Testing Accuracy: 0.8860212
# Step 7, Minibatch Loss= 0.6817, Training Accuracy= 0.891
# Testing Accuracy: 0.88939935
# Step 8, Minibatch Loss= 0.6750, Training Accuracy= 0.894
# Testing Accuracy: 0.89183164
# Step 9, Minibatch Loss= 0.6704, Training Accuracy= 0.896
# Testing Accuracy: 0.89325047
# Step 10, Minibatch Loss= 0.6660, Training Accuracy= 0.892
# Testing Accuracy: 0.8914938
# Step 11, Minibatch Loss= 0.6610, Training Accuracy= 0.895
# Testing Accuracy: 0.89271
# Step 12, Minibatch Loss= 0.6578, Training Accuracy= 0.895
# Testing Accuracy: 0.89196676
# Step 13, Minibatch Loss= 0.6546, Training Accuracy= 0.897
# Testing Accuracy: 0.89365584
# Step 14, Minibatch Loss= 0.6508, Training Accuracy= 0.897
# Testing Accuracy: 0.89250726
# Step 15, Minibatch Loss= 0.6465, Training Accuracy= 0.896
# Testing Accuracy: 0.8923046
# Step 16, Minibatch Loss= 0.6466, Training Accuracy= 0.895
# Testing Accuracy: 0.8902777
# Step 17, Minibatch Loss= 0.6450, Training Accuracy= 0.898
# Testing Accuracy: 0.8931829
# Step 18, Minibatch Loss= 0.6398, Training Accuracy= 0.895
# Testing Accuracy: 0.8910884
# Step 19, Minibatch Loss= 0.6387, Training Accuracy= 0.893
# Testing Accuracy: 0.88872373
# Step 20, Minibatch Loss= 0.6363, Training Accuracy= 0.893
# Testing Accuracy: 0.8893318
# Step 21, Minibatch Loss= 0.6347, Training Accuracy= 0.893
# Testing Accuracy: 0.8877103
# Step 22, Minibatch Loss= 0.6337, Training Accuracy= 0.893
# Testing Accuracy: 0.8886562
# Step 23, Minibatch Loss= 0.6323, Training Accuracy= 0.896
# Testing Accuracy: 0.8892642
# Step 24, Minibatch Loss= 0.6295, Training Accuracy= 0.898
# Testing Accuracy: 0.89183164
# Optimization Finished!
# Testing Accuracy: 0.89183164
# Step 1, Minibatch Loss= 0.8432, Training Accuracy= 0.915
# Testing Accuracy: 0.910952
# Step 2, Minibatch Loss= 0.7925, Training Accuracy= 0.910
# Testing Accuracy: 0.9054794
# Step 3, Minibatch Loss= 0.7622, Training Accuracy= 0.907
# Testing Accuracy: 0.9026417
# Step 4, Minibatch Loss= 0.7232, Training Accuracy= 0.901
# Testing Accuracy: 0.8948044
# Step 5, Minibatch Loss= 0.6943, Training Accuracy= 0.899
# Testing Accuracy: 0.89237213
# Step 6, Minibatch Loss= 0.6664, Training Accuracy= 0.898
# Testing Accuracy: 0.8904128
# Step 7, Minibatch Loss= 0.6395, Training Accuracy= 0.891
# Testing Accuracy: 0.88446724
# Step 8, Minibatch Loss= 0.6040, Training Accuracy= 0.888
# Testing Accuracy: 0.879873
# Step 9, Minibatch Loss= 0.5648, Training Accuracy= 0.891
# Testing Accuracy: 0.88446724
# Step 10, Minibatch Loss= 0.5295, Training Accuracy= 0.903
# Testing Accuracy: 0.89271
# Step 11, Minibatch Loss= 0.5198, Training Accuracy= 0.908
# Testing Accuracy: 0.90169585
# Step 12, Minibatch Loss= 0.4804, Training Accuracy= 0.908
# Testing Accuracy: 0.90115535
# Step 13, Minibatch Loss= 0.4714, Training Accuracy= 0.910
# Testing Accuracy: 0.9021012
# Step 14, Minibatch Loss= 0.4632, Training Accuracy= 0.917
# Testing Accuracy: 0.91027635
# Step 15, Minibatch Loss= 0.4557, Training Accuracy= 0.919
# Testing Accuracy: 0.9146004
# Step 16, Minibatch Loss= 0.4471, Training Accuracy= 0.922
# Testing Accuracy: 0.9161543
# Step 17, Minibatch Loss= 0.4425, Training Accuracy= 0.924
# Testing Accuracy: 0.91737044
# Step 18, Minibatch Loss= 0.4402, Training Accuracy= 0.926
# Testing Accuracy: 0.9190595
# Step 19, Minibatch Loss= 0.4347, Training Accuracy= 0.929
# Testing Accuracy: 0.9203432
# Step 20, Minibatch Loss= 0.4354, Training Accuracy= 0.928
# Testing Accuracy: 0.9202756
# Step 21, Minibatch Loss= 0.4335, Training Accuracy= 0.930
# Testing Accuracy: 0.9225728
# Step 22, Minibatch Loss= 0.4272, Training Accuracy= 0.930
# Testing Accuracy: 0.9212891
# Step 23, Minibatch Loss= 0.4312, Training Accuracy= 0.931
# Testing Accuracy: 0.9231809
# Step 24, Minibatch Loss= 0.4252, Training Accuracy= 0.930
# Testing Accuracy: 0.92304575
# Optimization Finished!
# Testing Accuracy: 0.92304575
# Step 1, Minibatch Loss= 0.9249, Training Accuracy= 0.907
# Testing Accuracy: 0.90297955
# Step 2, Minibatch Loss= 0.7621, Training Accuracy= 0.915
# Testing Accuracy: 0.910952
# Step 3, Minibatch Loss= 0.6886, Training Accuracy= 0.916
# Testing Accuracy: 0.9110195
# Step 4, Minibatch Loss= 0.6486, Training Accuracy= 0.916
# Testing Accuracy: 0.9112222
# Step 5, Minibatch Loss= 0.6180, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 6, Minibatch Loss= 0.5921, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 7, Minibatch Loss= 0.5766, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 8, Minibatch Loss= 0.5650, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 9, Minibatch Loss= 0.5568, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 10, Minibatch Loss= 0.5470, Training Accuracy= 0.916
# Testing Accuracy: 0.9116952
# Step 11, Minibatch Loss= 0.5363, Training Accuracy= 0.916
# Testing Accuracy: 0.9116952
# Step 12, Minibatch Loss= 0.5232, Training Accuracy= 0.916
# Testing Accuracy: 0.9116952
# Step 13, Minibatch Loss= 0.5198, Training Accuracy= 0.916
# Testing Accuracy: 0.9116952
# Step 14, Minibatch Loss= 0.5078, Training Accuracy= 0.916
# Testing Accuracy: 0.9116952
# Step 15, Minibatch Loss= 0.5032, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 16, Minibatch Loss= 0.5017, Training Accuracy= 0.802
# Testing Accuracy: 0.7930545
# Step 17, Minibatch Loss= 0.4961, Training Accuracy= 0.852
# Testing Accuracy: 0.84379435
# Step 18, Minibatch Loss= 0.4847, Training Accuracy= 0.872
# Testing Accuracy: 0.8652118
# Step 19, Minibatch Loss= 0.4822, Training Accuracy= 0.880
# Testing Accuracy: 0.87365717
# Step 20, Minibatch Loss= 0.4714, Training Accuracy= 0.897
# Testing Accuracy: 0.88777786
# Step 21, Minibatch Loss= 0.4664, Training Accuracy= 0.903
# Testing Accuracy: 0.89365584
# Step 22, Minibatch Loss= 0.4684, Training Accuracy= 0.907
# Testing Accuracy: 0.8975745
# Step 23, Minibatch Loss= 0.4640, Training Accuracy= 0.906
# Testing Accuracy: 0.895953
# Step 24, Minibatch Loss= 0.4608, Training Accuracy= 0.905
# Testing Accuracy: 0.8950071
# Optimization Finished!
# Testing Accuracy: 0.8950071
# Step 1, Minibatch Loss= 1.1524, Training Accuracy= 0.099
# Testing Accuracy: 0.10039862
# Step 2, Minibatch Loss= 0.9201, Training Accuracy= 0.915
# Testing Accuracy: 0.91074926
# Step 3, Minibatch Loss= 0.8412, Training Accuracy= 0.916
# Testing Accuracy: 0.91210055
# Step 4, Minibatch Loss= 0.8109, Training Accuracy= 0.916
# Testing Accuracy: 0.91203296
# Step 5, Minibatch Loss= 0.7998, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 6, Minibatch Loss= 0.7836, Training Accuracy= 0.916
# Testing Accuracy: 0.9110871
# Step 7, Minibatch Loss= 0.7574, Training Accuracy= 0.916
# Testing Accuracy: 0.9118303
# Step 8, Minibatch Loss= 0.7114, Training Accuracy= 0.915
# Testing Accuracy: 0.9119654
# Step 9, Minibatch Loss= 0.5941, Training Accuracy= 0.892
# Testing Accuracy: 0.8895345
# Step 10, Minibatch Loss= 0.5455, Training Accuracy= 0.913
# Testing Accuracy: 0.9080468
# Step 11, Minibatch Loss= 0.5024, Training Accuracy= 0.918
# Testing Accuracy: 0.91311395
# Step 12, Minibatch Loss= 0.4841, Training Accuracy= 0.930
# Testing Accuracy: 0.924397
# Step 13, Minibatch Loss= 0.4677, Training Accuracy= 0.933
# Testing Accuracy: 0.9267617
# Step 14, Minibatch Loss= 0.4530, Training Accuracy= 0.936
# Testing Accuracy: 0.92831564
# Step 15, Minibatch Loss= 0.4529, Training Accuracy= 0.936
# Testing Accuracy: 0.929194
# Step 16, Minibatch Loss= 0.4506, Training Accuracy= 0.938
# Testing Accuracy: 0.93209916
# Step 17, Minibatch Loss= 0.4431, Training Accuracy= 0.939
# Testing Accuracy: 0.93196404
# Step 18, Minibatch Loss= 0.4396, Training Accuracy= 0.939
# Testing Accuracy: 0.93209916
# Step 19, Minibatch Loss= 0.4371, Training Accuracy= 0.939
# Testing Accuracy: 0.93196404
# Step 20, Minibatch Loss= 0.4337, Training Accuracy= 0.940
# Testing Accuracy: 0.93290997
# Step 21, Minibatch Loss= 0.4338, Training Accuracy= 0.941
# Testing Accuracy: 0.93513954
# Step 22, Minibatch Loss= 0.4260, Training Accuracy= 0.939
# Testing Accuracy: 0.9311533
# Step 23, Minibatch Loss= 0.4254, Training Accuracy= 0.940
# Testing Accuracy: 0.9330451
# Step 24, Minibatch Loss= 0.4228, Training Accuracy= 0.941
# Testing Accuracy: 0.93277484
# Optimization Finished!
# Testing Accuracy: 0.93277484
# Step 1, Minibatch Loss= 0.8339, Training Accuracy= 0.886
# Testing Accuracy: 0.8802108
# Step 2, Minibatch Loss= 0.7233, Training Accuracy= 0.902
# Testing Accuracy: 0.8946693
# Step 3, Minibatch Loss= 0.6564, Training Accuracy= 0.898
# Testing Accuracy: 0.8933856
# Step 4, Minibatch Loss= 0.5974, Training Accuracy= 0.893
# Testing Accuracy: 0.886832
# Step 5, Minibatch Loss= 0.5496, Training Accuracy= 0.896
# Testing Accuracy: 0.8883859
# Step 6, Minibatch Loss= 0.5219, Training Accuracy= 0.897
# Testing Accuracy: 0.88825077
# Step 7, Minibatch Loss= 0.5083, Training Accuracy= 0.895
# Testing Accuracy: 0.88399434
# Step 8, Minibatch Loss= 0.4975, Training Accuracy= 0.897
# Testing Accuracy: 0.8824404
# Step 9, Minibatch Loss= 0.4768, Training Accuracy= 0.902
# Testing Accuracy: 0.8893318
# Step 10, Minibatch Loss= 0.4737, Training Accuracy= 0.907
# Testing Accuracy: 0.8950071
# Step 11, Minibatch Loss= 0.4626, Training Accuracy= 0.908
# Testing Accuracy: 0.89676374
# Step 12, Minibatch Loss= 0.4550, Training Accuracy= 0.918
# Testing Accuracy: 0.9081819
# Step 13, Minibatch Loss= 0.4520, Training Accuracy= 0.919
# Testing Accuracy: 0.90899265
# Step 14, Minibatch Loss= 0.4491, Training Accuracy= 0.918
# Testing Accuracy: 0.9093304
# Step 15, Minibatch Loss= 0.4457, Training Accuracy= 0.920
# Testing Accuracy: 0.9090602
# Step 16, Minibatch Loss= 0.4484, Training Accuracy= 0.910
# Testing Accuracy: 0.89750695
# Step 17, Minibatch Loss= 0.4360, Training Accuracy= 0.923
# Testing Accuracy: 0.9116952
# Step 18, Minibatch Loss= 0.4356, Training Accuracy= 0.927
# Testing Accuracy: 0.9177758
# Step 19, Minibatch Loss= 0.4319, Training Accuracy= 0.930
# Testing Accuracy: 0.9208837
# Step 20, Minibatch Loss= 0.4282, Training Accuracy= 0.930
# Testing Accuracy: 0.92054594
# Step 21, Minibatch Loss= 0.4285, Training Accuracy= 0.933
# Testing Accuracy: 0.92426187
# Step 22, Minibatch Loss= 0.4268, Training Accuracy= 0.931
# Testing Accuracy: 0.9218972
# Step 23, Minibatch Loss= 0.4225, Training Accuracy= 0.932
# Testing Accuracy: 0.92243767
# Step 24, Minibatch Loss= 0.4216, Training Accuracy= 0.934
# Testing Accuracy: 0.9232484
# Optimization Finished!
# Testing Accuracy: 0.9232484
# Step 1, Minibatch Loss= 1.0371, Training Accuracy= 0.905
# Testing Accuracy: 0.89797986
# Step 2, Minibatch Loss= 0.8405, Training Accuracy= 0.913
# Testing Accuracy: 0.9073711
# Step 3, Minibatch Loss= 0.7963, Training Accuracy= 0.913
# Testing Accuracy: 0.9081819
# Step 4, Minibatch Loss= 0.7692, Training Accuracy= 0.914
# Testing Accuracy: 0.9074387
# Step 5, Minibatch Loss= 0.7106, Training Accuracy= 0.912
# Testing Accuracy: 0.9036552
# Step 6, Minibatch Loss= 0.6238, Training Accuracy= 0.908
# Testing Accuracy: 0.9004797
# Step 7, Minibatch Loss= 0.5521, Training Accuracy= 0.910
# Testing Accuracy: 0.9025066
# Step 8, Minibatch Loss= 0.4890, Training Accuracy= 0.913
# Testing Accuracy: 0.90399295
# Step 9, Minibatch Loss= 0.4604, Training Accuracy= 0.927
# Testing Accuracy: 0.9185866
# Step 10, Minibatch Loss= 0.4442, Training Accuracy= 0.932
# Testing Accuracy: 0.92237014
# Step 11, Minibatch Loss= 0.4350, Training Accuracy= 0.936
# Testing Accuracy: 0.92791027
# Step 12, Minibatch Loss= 0.4294, Training Accuracy= 0.936
# Testing Accuracy: 0.9275049
# Step 13, Minibatch Loss= 0.4260, Training Accuracy= 0.937
# Testing Accuracy: 0.9291264
# Step 14, Minibatch Loss= 0.4234, Training Accuracy= 0.939
# Testing Accuracy: 0.93162626
# Step 15, Minibatch Loss= 0.4204, Training Accuracy= 0.939
# Testing Accuracy: 0.9316938
# Step 16, Minibatch Loss= 0.4186, Training Accuracy= 0.940
# Testing Accuracy: 0.9325721
# Step 17, Minibatch Loss= 0.4188, Training Accuracy= 0.939
# Testing Accuracy: 0.9322343
# Step 18, Minibatch Loss= 0.4155, Training Accuracy= 0.940
# Testing Accuracy: 0.932437
# Step 19, Minibatch Loss= 0.4161, Training Accuracy= 0.939
# Testing Accuracy: 0.93216676
# Step 20, Minibatch Loss= 0.4131, Training Accuracy= 0.941
# Testing Accuracy: 0.9331126
# Step 21, Minibatch Loss= 0.4143, Training Accuracy= 0.941
# Testing Accuracy: 0.933518
# Step 22, Minibatch Loss= 0.4158, Training Accuracy= 0.941
# Testing Accuracy: 0.93263966
# Step 23, Minibatch Loss= 0.4118, Training Accuracy= 0.942
# Testing Accuracy: 0.93378824
# Step 24, Minibatch Loss= 0.4108, Training Accuracy= 0.941
# Testing Accuracy: 0.93399096
# Optimization Finished!
# Testing Accuracy: 0.93399096
# Step 1, Minibatch Loss= 0.8667, Training Accuracy= 0.906
# Testing Accuracy: 0.9023039
# Step 2, Minibatch Loss= 0.8039, Training Accuracy= 0.915
# Testing Accuracy: 0.91074926
# Step 3, Minibatch Loss= 0.7947, Training Accuracy= 0.916
# Testing Accuracy: 0.9108844
# Step 4, Minibatch Loss= 0.7736, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 5, Minibatch Loss= 0.7183, Training Accuracy= 0.916
# Testing Accuracy: 0.9119654
# Step 6, Minibatch Loss= 0.6313, Training Accuracy= 0.917
# Testing Accuracy: 0.91149247
# Step 7, Minibatch Loss= 0.5656, Training Accuracy= 0.918
# Testing Accuracy: 0.9123708
# Step 8, Minibatch Loss= 0.5225, Training Accuracy= 0.923
# Testing Accuracy: 0.9171002
# Step 9, Minibatch Loss= 0.4933, Training Accuracy= 0.926
# Testing Accuracy: 0.9202756
# Step 10, Minibatch Loss= 0.4732, Training Accuracy= 0.932
# Testing Accuracy: 0.92608607
# Step 11, Minibatch Loss= 0.4580, Training Accuracy= 0.934
# Testing Accuracy: 0.9262888
# Step 12, Minibatch Loss= 0.4498, Training Accuracy= 0.938
# Testing Accuracy: 0.93108577
# Step 13, Minibatch Loss= 0.4494, Training Accuracy= 0.939
# Testing Accuracy: 0.93277484
# Step 14, Minibatch Loss= 0.4387, Training Accuracy= 0.939
# Testing Accuracy: 0.9329775
# Step 15, Minibatch Loss= 0.4505, Training Accuracy= 0.940
# Testing Accuracy: 0.9348017
# Step 16, Minibatch Loss= 0.4406, Training Accuracy= 0.941
# Testing Accuracy: 0.9355449
# Step 17, Minibatch Loss= 0.4352, Training Accuracy= 0.941
# Testing Accuracy: 0.93527466
# Step 18, Minibatch Loss= 0.4294, Training Accuracy= 0.941
# Testing Accuracy: 0.93527466
# Step 19, Minibatch Loss= 0.4326, Training Accuracy= 0.942
# Testing Accuracy: 0.9354098
# Step 20, Minibatch Loss= 0.4296, Training Accuracy= 0.942
# Testing Accuracy: 0.9354098
# Step 21, Minibatch Loss= 0.4299, Training Accuracy= 0.942
# Testing Accuracy: 0.93615294
# Step 22, Minibatch Loss= 0.4318, Training Accuracy= 0.942
# Testing Accuracy: 0.9359503
# Step 23, Minibatch Loss= 0.4243, Training Accuracy= 0.942
# Testing Accuracy: 0.93642324
# Step 24, Minibatch Loss= 0.4252, Training Accuracy= 0.942
# Testing Accuracy: 0.93655837
# Optimization Finished!
# Testing Accuracy: 0.93655837
# Step 1, Minibatch Loss= 0.8203, Training Accuracy= 0.894
# Testing Accuracy: 0.8916289
# Step 2, Minibatch Loss= 0.7123, Training Accuracy= 0.902
# Testing Accuracy: 0.8968313
# Step 3, Minibatch Loss= 0.6195, Training Accuracy= 0.900
# Testing Accuracy: 0.89433146
# Step 4, Minibatch Loss= 0.5345, Training Accuracy= 0.902
# Testing Accuracy: 0.8952773
# Step 5, Minibatch Loss= 0.5017, Training Accuracy= 0.906
# Testing Accuracy: 0.899196
# Step 6, Minibatch Loss= 0.4840, Training Accuracy= 0.909
# Testing Accuracy: 0.8996014
# Step 7, Minibatch Loss= 0.4685, Training Accuracy= 0.911
# Testing Accuracy: 0.9006824
# Step 8, Minibatch Loss= 0.4663, Training Accuracy= 0.919
# Testing Accuracy: 0.909398
# Step 9, Minibatch Loss= 0.4500, Training Accuracy= 0.919
# Testing Accuracy: 0.9099385
# Step 10, Minibatch Loss= 0.4534, Training Accuracy= 0.926
# Testing Accuracy: 0.91689754
# Step 11, Minibatch Loss= 0.4435, Training Accuracy= 0.928
# Testing Accuracy: 0.92047834
# Step 12, Minibatch Loss= 0.4317, Training Accuracy= 0.925
# Testing Accuracy: 0.91676235
# Step 13, Minibatch Loss= 0.4420, Training Accuracy= 0.933
# Testing Accuracy: 0.92608607
# Step 14, Minibatch Loss= 0.4261, Training Accuracy= 0.933
# Testing Accuracy: 0.92595094
# Step 15, Minibatch Loss= 0.4327, Training Accuracy= 0.932
# Testing Accuracy: 0.9250051
# Step 16, Minibatch Loss= 0.4266, Training Accuracy= 0.933
# Testing Accuracy: 0.92743737
# Step 17, Minibatch Loss= 0.4204, Training Accuracy= 0.931
# Testing Accuracy: 0.92534286
# Step 18, Minibatch Loss= 0.4237, Training Accuracy= 0.933
# Testing Accuracy: 0.92662656
# Step 19, Minibatch Loss= 0.4171, Training Accuracy= 0.933
# Testing Accuracy: 0.9268968
# Step 20, Minibatch Loss= 0.4209, Training Accuracy= 0.934
# Testing Accuracy: 0.928113
# Step 21, Minibatch Loss= 0.4228, Training Accuracy= 0.935
# Testing Accuracy: 0.92885613
# Step 22, Minibatch Loss= 0.4146, Training Accuracy= 0.934
# Testing Accuracy: 0.92764
# Step 23, Minibatch Loss= 0.4190, Training Accuracy= 0.935
# Testing Accuracy: 0.93027496
# Step 24, Minibatch Loss= 0.4198, Training Accuracy= 0.937
# Testing Accuracy: 0.9317614
# Optimization Finished!
# Testing Accuracy: 0.9317614
# Step 1, Minibatch Loss= 0.8729, Training Accuracy= 0.900
# Testing Accuracy: 0.8953449
# Step 2, Minibatch Loss= 0.7999, Training Accuracy= 0.913
# Testing Accuracy: 0.9070333
# Step 3, Minibatch Loss= 0.7510, Training Accuracy= 0.915
# Testing Accuracy: 0.9087224
# Step 4, Minibatch Loss= 0.6929, Training Accuracy= 0.906
# Testing Accuracy: 0.8989257
# Step 5, Minibatch Loss= 0.6453, Training Accuracy= 0.901
# Testing Accuracy: 0.8958854
# Step 6, Minibatch Loss= 0.5826, Training Accuracy= 0.898
# Testing Accuracy: 0.8909533
# Step 7, Minibatch Loss= 0.5318, Training Accuracy= 0.906
# Testing Accuracy: 0.900277
# Step 8, Minibatch Loss= 0.5046, Training Accuracy= 0.911
# Testing Accuracy: 0.90460104
# Step 9, Minibatch Loss= 0.4855, Training Accuracy= 0.918
# Testing Accuracy: 0.91156006
# Step 10, Minibatch Loss= 0.4673, Training Accuracy= 0.918
# Testing Accuracy: 0.91074926
# Step 11, Minibatch Loss= 0.4588, Training Accuracy= 0.926
# Testing Accuracy: 0.918992
# Step 12, Minibatch Loss= 0.4515, Training Accuracy= 0.927
# Testing Accuracy: 0.9202081
# Step 13, Minibatch Loss= 0.4498, Training Accuracy= 0.927
# Testing Accuracy: 0.92169446
# Step 14, Minibatch Loss= 0.4442, Training Accuracy= 0.928
# Testing Accuracy: 0.922235
# Step 15, Minibatch Loss= 0.4410, Training Accuracy= 0.929
# Testing Accuracy: 0.924397
# Step 16, Minibatch Loss= 0.4338, Training Accuracy= 0.932
# Testing Accuracy: 0.9256131
# Step 17, Minibatch Loss= 0.4303, Training Accuracy= 0.933
# Testing Accuracy: 0.9258834
# Step 18, Minibatch Loss= 0.4253, Training Accuracy= 0.936
# Testing Accuracy: 0.92845076
# Step 19, Minibatch Loss= 0.4250, Training Accuracy= 0.935
# Testing Accuracy: 0.92926157
# Step 20, Minibatch Loss= 0.4259, Training Accuracy= 0.939
# Testing Accuracy: 0.93338287
# Step 21, Minibatch Loss= 0.4235, Training Accuracy= 0.940
# Testing Accuracy: 0.9341936
# Step 22, Minibatch Loss= 0.4218, Training Accuracy= 0.941
# Testing Accuracy: 0.93453145
# Step 23, Minibatch Loss= 0.4203, Training Accuracy= 0.939
# Testing Accuracy: 0.93324775
# Step 24, Minibatch Loss= 0.4176, Training Accuracy= 0.939
# Testing Accuracy: 0.93277484
# Optimization Finished!
# Testing Accuracy: 0.93277484
# Step 1, Minibatch Loss= 0.8999, Training Accuracy= 0.833
# Testing Accuracy: 0.8263631
# Step 2, Minibatch Loss= 0.7304, Training Accuracy= 0.888
# Testing Accuracy: 0.87683266
# Step 3, Minibatch Loss= 0.6892, Training Accuracy= 0.889
# Testing Accuracy: 0.8822377
# Step 4, Minibatch Loss= 0.6568, Training Accuracy= 0.885
# Testing Accuracy: 0.87784606
# Step 5, Minibatch Loss= 0.6268, Training Accuracy= 0.882
# Testing Accuracy: 0.8723059
# Step 6, Minibatch Loss= 0.5982, Training Accuracy= 0.879
# Testing Accuracy: 0.87081957
# Step 7, Minibatch Loss= 0.5682, Training Accuracy= 0.877
# Testing Accuracy: 0.8671711
# Step 8, Minibatch Loss= 0.5404, Training Accuracy= 0.879
# Testing Accuracy: 0.8678468
# Step 9, Minibatch Loss= 0.5151, Training Accuracy= 0.884
# Testing Accuracy: 0.8725762
# Step 10, Minibatch Loss= 0.4939, Training Accuracy= 0.889
# Testing Accuracy: 0.8775083
# Step 11, Minibatch Loss= 0.4749, Training Accuracy= 0.896
# Testing Accuracy: 0.88460237
# Step 12, Minibatch Loss= 0.4629, Training Accuracy= 0.904
# Testing Accuracy: 0.8952098
# Step 13, Minibatch Loss= 0.4515, Training Accuracy= 0.915
# Testing Accuracy: 0.9063577
# Step 14, Minibatch Loss= 0.4456, Training Accuracy= 0.921
# Testing Accuracy: 0.91372204
# Step 15, Minibatch Loss= 0.4410, Training Accuracy= 0.925
# Testing Accuracy: 0.91703266
# Step 16, Minibatch Loss= 0.4364, Training Accuracy= 0.929
# Testing Accuracy: 0.9213567
# Step 17, Minibatch Loss= 0.4331, Training Accuracy= 0.932
# Testing Accuracy: 0.9237889
# Step 18, Minibatch Loss= 0.4346, Training Accuracy= 0.934
# Testing Accuracy: 0.9258834
# Step 19, Minibatch Loss= 0.4271, Training Accuracy= 0.936
# Testing Accuracy: 0.9267617
# Step 20, Minibatch Loss= 0.4244, Training Accuracy= 0.937
# Testing Accuracy: 0.9277076
# Step 21, Minibatch Loss= 0.4198, Training Accuracy= 0.937
# Testing Accuracy: 0.92743737
# Step 22, Minibatch Loss= 0.4196, Training Accuracy= 0.938
# Testing Accuracy: 0.92797786
# Step 23, Minibatch Loss= 0.4216, Training Accuracy= 0.938
# Testing Accuracy: 0.92845076
# Step 24, Minibatch Loss= 0.4211, Training Accuracy= 0.938
# Testing Accuracy: 0.9282481
# Optimization Finished!
# Testing Accuracy: 0.9282481
# Step 1, Minibatch Loss= 0.8187, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 2, Minibatch Loss= 0.7802, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 3, Minibatch Loss= 0.7141, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 4, Minibatch Loss= 0.6336, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 5, Minibatch Loss= 0.5719, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 6, Minibatch Loss= 0.5384, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 7, Minibatch Loss= 0.5181, Training Accuracy= 0.836
# Testing Accuracy: 0.830079
# Step 8, Minibatch Loss= 0.5033, Training Accuracy= 0.848
# Testing Accuracy: 0.84075403
# Step 9, Minibatch Loss= 0.4951, Training Accuracy= 0.851
# Testing Accuracy: 0.84555095
# Step 10, Minibatch Loss= 0.4879, Training Accuracy= 0.864
# Testing Accuracy: 0.8603473
# Step 11, Minibatch Loss= 0.4825, Training Accuracy= 0.879
# Testing Accuracy: 0.8739274
# Step 12, Minibatch Loss= 0.4752, Training Accuracy= 0.896
# Testing Accuracy: 0.88872373
# Step 13, Minibatch Loss= 0.4675, Training Accuracy= 0.904
# Testing Accuracy: 0.8964935
# Step 14, Minibatch Loss= 0.4621, Training Accuracy= 0.907
# Testing Accuracy: 0.8997365
# Step 15, Minibatch Loss= 0.4552, Training Accuracy= 0.910
# Testing Accuracy: 0.90297955
# Step 16, Minibatch Loss= 0.4480, Training Accuracy= 0.912
# Testing Accuracy: 0.906155
# Step 17, Minibatch Loss= 0.4420, Training Accuracy= 0.912
# Testing Accuracy: 0.9036552
# Step 18, Minibatch Loss= 0.4409, Training Accuracy= 0.916
# Testing Accuracy: 0.90770894
# Step 19, Minibatch Loss= 0.4366, Training Accuracy= 0.914
# Testing Accuracy: 0.90662795
# Step 20, Minibatch Loss= 0.4336, Training Accuracy= 0.914
# Testing Accuracy: 0.90588474
# Step 21, Minibatch Loss= 0.4288, Training Accuracy= 0.916
# Testing Accuracy: 0.9067631
# Step 22, Minibatch Loss= 0.4269, Training Accuracy= 0.913
# Testing Accuracy: 0.9031822
# Step 23, Minibatch Loss= 0.4250, Training Accuracy= 0.916
# Testing Accuracy: 0.90588474
# Step 24, Minibatch Loss= 0.4231, Training Accuracy= 0.914
# Testing Accuracy: 0.9027093
# Optimization Finished!
# Testing Accuracy: 0.9027093
# Step 1, Minibatch Loss= 0.8488, Training Accuracy= 0.901
# Testing Accuracy: 0.8962908
# Step 2, Minibatch Loss= 0.7539, Training Accuracy= 0.911
# Testing Accuracy: 0.90480375
# Step 3, Minibatch Loss= 0.6767, Training Accuracy= 0.912
# Testing Accuracy: 0.906155
# Step 4, Minibatch Loss= 0.5964, Training Accuracy= 0.914
# Testing Accuracy: 0.908317
# Step 5, Minibatch Loss= 0.5462, Training Accuracy= 0.917
# Testing Accuracy: 0.9110195
# Step 6, Minibatch Loss= 0.5141, Training Accuracy= 0.912
# Testing Accuracy: 0.9048713
# Step 7, Minibatch Loss= 0.4942, Training Accuracy= 0.886
# Testing Accuracy: 0.8763597
# Step 8, Minibatch Loss= 0.4767, Training Accuracy= 0.897
# Testing Accuracy: 0.88993984
# Step 9, Minibatch Loss= 0.4569, Training Accuracy= 0.932
# Testing Accuracy: 0.92601854
# Step 10, Minibatch Loss= 0.4451, Training Accuracy= 0.935
# Testing Accuracy: 0.9281805
# Step 11, Minibatch Loss= 0.4393, Training Accuracy= 0.937
# Testing Accuracy: 0.9295318
# Step 12, Minibatch Loss= 0.4343, Training Accuracy= 0.938
# Testing Accuracy: 0.9309506
# Step 13, Minibatch Loss= 0.4328, Training Accuracy= 0.939
# Testing Accuracy: 0.93196404
# Step 14, Minibatch Loss= 0.4292, Training Accuracy= 0.938
# Testing Accuracy: 0.9318965
# Step 15, Minibatch Loss= 0.4303, Training Accuracy= 0.939
# Testing Accuracy: 0.9329775
# Step 16, Minibatch Loss= 0.4283, Training Accuracy= 0.939
# Testing Accuracy: 0.9328424
# Step 17, Minibatch Loss= 0.4222, Training Accuracy= 0.940
# Testing Accuracy: 0.93378824
# Step 18, Minibatch Loss= 0.4244, Training Accuracy= 0.940
# Testing Accuracy: 0.933518
# Step 19, Minibatch Loss= 0.4201, Training Accuracy= 0.940
# Testing Accuracy: 0.93459904
# Step 20, Minibatch Loss= 0.4192, Training Accuracy= 0.940
# Testing Accuracy: 0.9348693
# Step 21, Minibatch Loss= 0.4160, Training Accuracy= 0.940
# Testing Accuracy: 0.93473417
# Step 22, Minibatch Loss= 0.4218, Training Accuracy= 0.941
# Testing Accuracy: 0.93507195
# Step 23, Minibatch Loss= 0.4190, Training Accuracy= 0.941
# Testing Accuracy: 0.93527466
# Step 24, Minibatch Loss= 0.4163, Training Accuracy= 0.941
# Testing Accuracy: 0.93513954
# Optimization Finished!
# Testing Accuracy: 0.93513954
# Step 1, Minibatch Loss= 0.8281, Training Accuracy= 0.915
# Testing Accuracy: 0.9110195
# Step 2, Minibatch Loss= 0.8001, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 3, Minibatch Loss= 0.7851, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 4, Minibatch Loss= 0.7558, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 5, Minibatch Loss= 0.6922, Training Accuracy= 0.916
# Testing Accuracy: 0.91149247
# Step 6, Minibatch Loss= 0.6186, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 7, Minibatch Loss= 0.5775, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 8, Minibatch Loss= 0.5537, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 9, Minibatch Loss= 0.5420, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 10, Minibatch Loss= 0.5332, Training Accuracy= 0.916
# Testing Accuracy: 0.9116952
# Step 11, Minibatch Loss= 0.5274, Training Accuracy= 0.916
# Testing Accuracy: 0.9119654
# Step 12, Minibatch Loss= 0.5180, Training Accuracy= 0.916
# Testing Accuracy: 0.9122357
# Step 13, Minibatch Loss= 0.5153, Training Accuracy= 0.916
# Testing Accuracy: 0.91203296
# Step 14, Minibatch Loss= 0.5134, Training Accuracy= 0.915
# Testing Accuracy: 0.9101412
# Step 15, Minibatch Loss= 0.5098, Training Accuracy= 0.916
# Testing Accuracy: 0.91203296
# Step 16, Minibatch Loss= 0.4995, Training Accuracy= 0.917
# Testing Accuracy: 0.91135734
# Step 17, Minibatch Loss= 0.4782, Training Accuracy= 0.927
# Testing Accuracy: 0.9225728
# Step 18, Minibatch Loss= 0.4548, Training Accuracy= 0.934
# Testing Accuracy: 0.9285859
# Step 19, Minibatch Loss= 0.4421, Training Accuracy= 0.932
# Testing Accuracy: 0.92595094
# Step 20, Minibatch Loss= 0.4340, Training Accuracy= 0.935
# Testing Accuracy: 0.9285859
# Step 21, Minibatch Loss= 0.4306, Training Accuracy= 0.939
# Testing Accuracy: 0.93338287
# Step 22, Minibatch Loss= 0.4269, Training Accuracy= 0.940
# Testing Accuracy: 0.9336531
# Step 23, Minibatch Loss= 0.4259, Training Accuracy= 0.941
# Testing Accuracy: 0.93574756
# Step 24, Minibatch Loss= 0.4278, Training Accuracy= 0.942
# Testing Accuracy: 0.93615294
# Optimization Finished!
# Testing Accuracy: 0.93615294
# Step 1, Minibatch Loss= 0.8825, Training Accuracy= 0.912
# Testing Accuracy: 0.90406054
# Step 2, Minibatch Loss= 0.7868, Training Accuracy= 0.916
# Testing Accuracy: 0.91061413
# Step 3, Minibatch Loss= 0.7577, Training Accuracy= 0.917
# Testing Accuracy: 0.910952
# Step 4, Minibatch Loss= 0.7417, Training Accuracy= 0.919
# Testing Accuracy: 0.9123032
# Step 5, Minibatch Loss= 0.7178, Training Accuracy= 0.920
# Testing Accuracy: 0.9135194
# Step 6, Minibatch Loss= 0.6965, Training Accuracy= 0.922
# Testing Accuracy: 0.91554624
# Step 7, Minibatch Loss= 0.6528, Training Accuracy= 0.927
# Testing Accuracy: 0.92047834
# Step 8, Minibatch Loss= 0.6285, Training Accuracy= 0.930
# Testing Accuracy: 0.9234511
# Step 9, Minibatch Loss= 0.6027, Training Accuracy= 0.930
# Testing Accuracy: 0.92284304
# Step 10, Minibatch Loss= 0.5816, Training Accuracy= 0.935
# Testing Accuracy: 0.9277076
# Step 11, Minibatch Loss= 0.5521, Training Accuracy= 0.936
# Testing Accuracy: 0.9289237
# Step 12, Minibatch Loss= 0.5111, Training Accuracy= 0.939
# Testing Accuracy: 0.9306128
# Step 13, Minibatch Loss= 0.4786, Training Accuracy= 0.940
# Testing Accuracy: 0.93290997
# Step 14, Minibatch Loss= 0.4550, Training Accuracy= 0.941
# Testing Accuracy: 0.93345046
# Step 15, Minibatch Loss= 0.4489, Training Accuracy= 0.942
# Testing Accuracy: 0.93459904
# Step 16, Minibatch Loss= 0.4458, Training Accuracy= 0.941
# Testing Accuracy: 0.9354098
# Step 17, Minibatch Loss= 0.4417, Training Accuracy= 0.942
# Testing Accuracy: 0.9355449
# Step 18, Minibatch Loss= 0.4382, Training Accuracy= 0.942
# Testing Accuracy: 0.93568003
# Step 19, Minibatch Loss= 0.4381, Training Accuracy= 0.942
# Testing Accuracy: 0.93615294
# Step 20, Minibatch Loss= 0.4331, Training Accuracy= 0.942
# Testing Accuracy: 0.9354098
# Step 21, Minibatch Loss= 0.4355, Training Accuracy= 0.943
# Testing Accuracy: 0.9362881
# Step 22, Minibatch Loss= 0.4297, Training Accuracy= 0.943
# Testing Accuracy: 0.93703127
# Step 23, Minibatch Loss= 0.4262, Training Accuracy= 0.943
# Testing Accuracy: 0.93750423
# Step 24, Minibatch Loss= 0.4258, Training Accuracy= 0.943
# Testing Accuracy: 0.9373691
# Optimization Finished!
# Testing Accuracy: 0.9373691
# Step 1, Minibatch Loss= 0.8175, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 2, Minibatch Loss= 0.7255, Training Accuracy= 0.892
# Testing Accuracy: 0.8856158
# Step 3, Minibatch Loss= 0.5961, Training Accuracy= 0.795
# Testing Accuracy: 0.79210865
# Step 4, Minibatch Loss= 0.5290, Training Accuracy= 0.921
# Testing Accuracy: 0.91811365
# Step 5, Minibatch Loss= 0.4981, Training Accuracy= 0.923
# Testing Accuracy: 0.9183839
# Step 6, Minibatch Loss= 0.4674, Training Accuracy= 0.932
# Testing Accuracy: 0.9268968
# Step 7, Minibatch Loss= 0.4466, Training Accuracy= 0.937
# Testing Accuracy: 0.9312209
# Step 8, Minibatch Loss= 0.4413, Training Accuracy= 0.939
# Testing Accuracy: 0.9322343
# Step 9, Minibatch Loss= 0.4358, Training Accuracy= 0.940
# Testing Accuracy: 0.9340585
# Step 10, Minibatch Loss= 0.4331, Training Accuracy= 0.941
# Testing Accuracy: 0.93453145
# Step 11, Minibatch Loss= 0.4306, Training Accuracy= 0.941
# Testing Accuracy: 0.9346666
# Step 12, Minibatch Loss= 0.4321, Training Accuracy= 0.941
# Testing Accuracy: 0.93507195
# Step 13, Minibatch Loss= 0.4308, Training Accuracy= 0.942
# Testing Accuracy: 0.9354098
# Step 14, Minibatch Loss= 0.4290, Training Accuracy= 0.943
# Testing Accuracy: 0.93581516
# Step 15, Minibatch Loss= 0.4280, Training Accuracy= 0.942
# Testing Accuracy: 0.93574756
# Step 16, Minibatch Loss= 0.4241, Training Accuracy= 0.942
# Testing Accuracy: 0.93574756
# Step 17, Minibatch Loss= 0.4244, Training Accuracy= 0.943
# Testing Accuracy: 0.9362205
# Step 18, Minibatch Loss= 0.4230, Training Accuracy= 0.942
# Testing Accuracy: 0.93568003
# Step 19, Minibatch Loss= 0.4204, Training Accuracy= 0.943
# Testing Accuracy: 0.9362205
# Step 20, Minibatch Loss= 0.4209, Training Accuracy= 0.943
# Testing Accuracy: 0.9366259
# Step 21, Minibatch Loss= 0.4171, Training Accuracy= 0.943
# Testing Accuracy: 0.9359503
# Step 22, Minibatch Loss= 0.4177, Training Accuracy= 0.943
# Testing Accuracy: 0.93568003
# Step 23, Minibatch Loss= 0.4164, Training Accuracy= 0.943
# Testing Accuracy: 0.93568003
# Step 24, Minibatch Loss= 0.4149, Training Accuracy= 0.943
# Testing Accuracy: 0.9359503
# Optimization Finished!
# Testing Accuracy: 0.9359503
# Step 1, Minibatch Loss= 0.8210, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 2, Minibatch Loss= 0.8065, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 3, Minibatch Loss= 0.7994, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 4, Minibatch Loss= 0.7785, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 5, Minibatch Loss= 0.7289, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 6, Minibatch Loss= 0.6503, Training Accuracy= 0.916
# Testing Accuracy: 0.91149247
# Step 7, Minibatch Loss= 0.5862, Training Accuracy= 0.916
# Testing Accuracy: 0.91149247
# Step 8, Minibatch Loss= 0.5476, Training Accuracy= 0.916
# Testing Accuracy: 0.91156006
# Step 9, Minibatch Loss= 0.5378, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 10, Minibatch Loss= 0.5321, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 11, Minibatch Loss= 0.5278, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 12, Minibatch Loss= 0.5237, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 13, Minibatch Loss= 0.5216, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 14, Minibatch Loss= 0.5122, Training Accuracy= 0.916
# Testing Accuracy: 0.9116276
# Step 15, Minibatch Loss= 0.4934, Training Accuracy= 0.791
# Testing Accuracy: 0.78514963
# Step 16, Minibatch Loss= 0.4885, Training Accuracy= 0.812
# Testing Accuracy: 0.80595905
# Step 17, Minibatch Loss= 0.4865, Training Accuracy= 0.823
# Testing Accuracy: 0.81751233
# Step 18, Minibatch Loss= 0.4828, Training Accuracy= 0.828
# Testing Accuracy: 0.82183635
# Step 19, Minibatch Loss= 0.4761, Training Accuracy= 0.838
# Testing Accuracy: 0.83149785
# Step 20, Minibatch Loss= 0.4724, Training Accuracy= 0.849
# Testing Accuracy: 0.8402135
# Step 21, Minibatch Loss= 0.4680, Training Accuracy= 0.858
# Testing Accuracy: 0.84805083
# Step 22, Minibatch Loss= 0.4655, Training Accuracy= 0.865
# Testing Accuracy: 0.8525775
# Step 23, Minibatch Loss= 0.4566, Training Accuracy= 0.888
# Testing Accuracy: 0.87771094
# Step 24, Minibatch Loss= 0.4497, Training Accuracy= 0.893
# Testing Accuracy: 0.88176477
# Optimization Finished!
# Testing Accuracy: 0.88176477
# Step 1, Minibatch Loss= 0.8995, Training Accuracy= 0.898
# Testing Accuracy: 0.8944666
# Step 2, Minibatch Loss= 0.7810, Training Accuracy= 0.907
# Testing Accuracy: 0.9031822
# Step 3, Minibatch Loss= 0.7129, Training Accuracy= 0.906
# Testing Accuracy: 0.90297955
# Step 4, Minibatch Loss= 0.6531, Training Accuracy= 0.906
# Testing Accuracy: 0.90095264
# Step 5, Minibatch Loss= 0.5960, Training Accuracy= 0.903
# Testing Accuracy: 0.8968313
# Step 6, Minibatch Loss= 0.5587, Training Accuracy= 0.897
# Testing Accuracy: 0.8902777
# Step 7, Minibatch Loss= 0.5289, Training Accuracy= 0.892
# Testing Accuracy: 0.8837241
# Step 8, Minibatch Loss= 0.5095, Training Accuracy= 0.893
# Testing Accuracy: 0.883116
# Step 9, Minibatch Loss= 0.4892, Training Accuracy= 0.902
# Testing Accuracy: 0.89304775
# Step 10, Minibatch Loss= 0.4673, Training Accuracy= 0.903
# Testing Accuracy: 0.89358824
# Step 11, Minibatch Loss= 0.4581, Training Accuracy= 0.906
# Testing Accuracy: 0.89858794
# Step 12, Minibatch Loss= 0.4487, Training Accuracy= 0.911
# Testing Accuracy: 0.9028444
# Step 13, Minibatch Loss= 0.4438, Training Accuracy= 0.915
# Testing Accuracy: 0.9075062
# Step 14, Minibatch Loss= 0.4416, Training Accuracy= 0.918
# Testing Accuracy: 0.9092629
# Step 15, Minibatch Loss= 0.4321, Training Accuracy= 0.922
# Testing Accuracy: 0.91257346
# Step 16, Minibatch Loss= 0.4320, Training Accuracy= 0.923
# Testing Accuracy: 0.9129113
# Step 17, Minibatch Loss= 0.4308, Training Accuracy= 0.921
# Testing Accuracy: 0.90899265
# Step 18, Minibatch Loss= 0.4316, Training Accuracy= 0.921
# Testing Accuracy: 0.90838456
# Step 19, Minibatch Loss= 0.4292, Training Accuracy= 0.924
# Testing Accuracy: 0.9110195
# Step 20, Minibatch Loss= 0.4282, Training Accuracy= 0.926
# Testing Accuracy: 0.91372204
# Step 21, Minibatch Loss= 0.4231, Training Accuracy= 0.927
# Testing Accuracy: 0.9146004
# Step 22, Minibatch Loss= 0.4247, Training Accuracy= 0.927
# Testing Accuracy: 0.91561383
# Step 23, Minibatch Loss= 0.4263, Training Accuracy= 0.930
# Testing Accuracy: 0.9204108
# Step 24, Minibatch Loss= 0.4184, Training Accuracy= 0.925
# Testing Accuracy: 0.91331667
# Optimization Finished!
# Testing Accuracy: 0.91331667
# Step 1, Minibatch Loss= 0.8165, Training Accuracy= 0.912
# Testing Accuracy: 0.9059523
# Step 2, Minibatch Loss= 0.7925, Training Accuracy= 0.917
# Testing Accuracy: 0.9103439
# Step 3, Minibatch Loss= 0.7719, Training Accuracy= 0.917
# Testing Accuracy: 0.910952
# Step 4, Minibatch Loss= 0.7446, Training Accuracy= 0.920
# Testing Accuracy: 0.91385716
# Step 5, Minibatch Loss= 0.6964, Training Accuracy= 0.925
# Testing Accuracy: 0.9178434
# Step 6, Minibatch Loss= 0.6370, Training Accuracy= 0.929
# Testing Accuracy: 0.920073
# Step 7, Minibatch Loss= 0.5716, Training Accuracy= 0.932
# Testing Accuracy: 0.92426187
# Step 8, Minibatch Loss= 0.5175, Training Accuracy= 0.933
# Testing Accuracy: 0.9268293
# Step 9, Minibatch Loss= 0.4819, Training Accuracy= 0.934
# Testing Accuracy: 0.9287886
# Step 10, Minibatch Loss= 0.4579, Training Accuracy= 0.935
# Testing Accuracy: 0.9293291
# Step 11, Minibatch Loss= 0.4476, Training Accuracy= 0.934
# Testing Accuracy: 0.92959934
# Step 12, Minibatch Loss= 0.4424, Training Accuracy= 0.935
# Testing Accuracy: 0.9293291
# Step 13, Minibatch Loss= 0.4354, Training Accuracy= 0.936
# Testing Accuracy: 0.9304777
# Step 14, Minibatch Loss= 0.4321, Training Accuracy= 0.936
# Testing Accuracy: 0.9298696
# Step 15, Minibatch Loss= 0.4294, Training Accuracy= 0.934
# Testing Accuracy: 0.92838323
# Step 16, Minibatch Loss= 0.4261, Training Accuracy= 0.935
# Testing Accuracy: 0.92831564
# Step 17, Minibatch Loss= 0.4259, Training Accuracy= 0.933
# Testing Accuracy: 0.92655903
# Step 18, Minibatch Loss= 0.4219, Training Accuracy= 0.934
# Testing Accuracy: 0.92716706
# Step 19, Minibatch Loss= 0.4193, Training Accuracy= 0.934
# Testing Accuracy: 0.92777514
# Step 20, Minibatch Loss= 0.4181, Training Accuracy= 0.934
# Testing Accuracy: 0.9275725
# Step 21, Minibatch Loss= 0.4173, Training Accuracy= 0.934
# Testing Accuracy: 0.9273698
# Step 22, Minibatch Loss= 0.4165, Training Accuracy= 0.935
# Testing Accuracy: 0.92831564
# Step 23, Minibatch Loss= 0.4150, Training Accuracy= 0.934
# Testing Accuracy: 0.92669415
# Step 24, Minibatch Loss= 0.4135, Training Accuracy= 0.934
# Testing Accuracy: 0.92777514
# Optimization Finished!
# Testing Accuracy: 0.92777514
# Step 1, Minibatch Loss= 0.8914, Training Accuracy= 0.889
# Testing Accuracy: 0.88217014
# Step 2, Minibatch Loss= 0.7605, Training Accuracy= 0.908
# Testing Accuracy: 0.90352005
# Step 3, Minibatch Loss= 0.7111, Training Accuracy= 0.911
# Testing Accuracy: 0.9062901
# Step 4, Minibatch Loss= 0.6678, Training Accuracy= 0.911
# Testing Accuracy: 0.9062901
# Step 5, Minibatch Loss= 0.6275, Training Accuracy= 0.911
# Testing Accuracy: 0.90656036
# Step 6, Minibatch Loss= 0.5899, Training Accuracy= 0.913
# Testing Accuracy: 0.90878993
# Step 7, Minibatch Loss= 0.5562, Training Accuracy= 0.842
# Testing Accuracy: 0.83953786
# Step 8, Minibatch Loss= 0.5277, Training Accuracy= 0.835
# Testing Accuracy: 0.83210593
# Step 9, Minibatch Loss= 0.4947, Training Accuracy= 0.926
# Testing Accuracy: 0.9196676
# Step 10, Minibatch Loss= 0.4713, Training Accuracy= 0.931
# Testing Accuracy: 0.924397
# Step 11, Minibatch Loss= 0.4520, Training Accuracy= 0.935
# Testing Accuracy: 0.92764
# Step 12, Minibatch Loss= 0.4407, Training Accuracy= 0.936
# Testing Accuracy: 0.9289237
# Step 13, Minibatch Loss= 0.4354, Training Accuracy= 0.939
# Testing Accuracy: 0.931356
# Step 14, Minibatch Loss= 0.4291, Training Accuracy= 0.940
# Testing Accuracy: 0.9323694
# Step 15, Minibatch Loss= 0.4263, Training Accuracy= 0.940
# Testing Accuracy: 0.93263966
# Step 16, Minibatch Loss= 0.4243, Training Accuracy= 0.941
# Testing Accuracy: 0.93446386
# Step 17, Minibatch Loss= 0.4243, Training Accuracy= 0.942
# Testing Accuracy: 0.9348693
# Step 18, Minibatch Loss= 0.4221, Training Accuracy= 0.942
# Testing Accuracy: 0.93507195
# Step 19, Minibatch Loss= 0.4175, Training Accuracy= 0.942
# Testing Accuracy: 0.9348693
# Step 20, Minibatch Loss= 0.4167, Training Accuracy= 0.943
# Testing Accuracy: 0.9354098
# Step 21, Minibatch Loss= 0.4150, Training Accuracy= 0.942
# Testing Accuracy: 0.9348693
# Step 22, Minibatch Loss= 0.4140, Training Accuracy= 0.943
# Testing Accuracy: 0.9362881
# Step 23, Minibatch Loss= 0.4156, Training Accuracy= 0.943
# Testing Accuracy: 0.9355449
# Step 24, Minibatch Loss= 0.4132, Training Accuracy= 0.943
# Testing Accuracy: 0.9355449
# Optimization Finished!
# Testing Accuracy: 0.9355449

# %%
df_met=pd.DataFrame(all_metrics,columns=['C_name','Accuracy','Notpromoted_rec','Promoted_rec','notpromoted_prec','promoted_prec','fscore_nonprom','fscore_prom'])

# %%
t=df_met.sort_values('Promoted_rec',ascending=True)
t[['C_name','Accuracy','Promoted_rec','promoted_prec','fscore_prom','notpromoted_prec','Notpromoted_rec','fscore_nonprom']]
# Out:
#                           C_name  Accuracy  Promoted_rec  promoted_prec  \
# 5              length_of_service  0.911628      0.000000       0.000000
# 8             avg_training_score  0.891832      0.196483       0.318463
# 21    education_Master's & above  0.937369      0.314220       0.931973
# 20     education_Below Secondary  0.936153      0.324159       0.874227
# 22                      gender_f  0.935950      0.326453       0.864372
# 26  recruitment_channel_sourcing  0.935545      0.329511       0.848425
# 14        department_Procurement  0.936558      0.330275       0.872727
# 1                         region  0.934194      0.331040       0.813910
# 7                    awards_won?  0.932437      0.332569       0.774021
# 13         department_Operations  0.933991      0.334862       0.803670
# 11                 department_HR  0.932775      0.338685       0.773124
# 16  department_Sales & Marketing  0.932775      0.344801       0.765705
# 19          education_Bachelor's  0.935140      0.346330       0.811828
# 17         department_Technology  0.928248      0.347859       0.685241
# 4           previous_year_rating  0.934869      0.347859       0.803887
# 6                  KPIs_met >80%  0.924735      0.373089       0.624041
# 15                department_R&D  0.931761      0.373089       0.719764
# 12              department_Legal  0.923248      0.373853       0.606700
# 25  recruitment_channel_referred  0.927775      0.379205       0.658699
# 9           department_Analytics  0.923046      0.388379       0.599764
# 0                    employee_id  0.921492      0.390673       0.583333
# 3                            age  0.922843      0.396024       0.595402
# 24     recruitment_channel_other  0.913317      0.401376       0.512195
# 2                no_of_trainings  0.918316      0.402141       0.551941
# 10            department_Finance  0.895007      0.444954       0.412766
# 18                  education_-1  0.902709      0.463303       0.450893
# 23                      gender_m  0.881765      0.511468       0.375843
#
#     fscore_prom  notpromoted_prec  Notpromoted_rec  fscore_nonprom
# 5      0.000000          0.911628         1.000000        0.953771
# 8      0.243026          0.924896         0.959238        0.941754
# 21     0.469983          0.937535         0.997777        0.966718
# 20     0.472950          0.938251         0.995479        0.966018
# 22     0.473918          0.938422         0.995034        0.965899
# 26     0.474670          0.938641         0.994293        0.965666
# 14     0.479201          0.938767         0.995331        0.966222
# 1      0.470652          0.938678         0.992663        0.964916
# 7      0.465241          0.938690         0.990588        0.963941
# 13     0.472747          0.938973         0.992070        0.964792
# 11     0.471026          0.939204         0.990365        0.964107
# 16     0.475488          0.939699         0.989772        0.964086
# 19     0.485531          0.939971         0.992218        0.965388
# 17     0.461460          0.939662         0.984510        0.961564
# 4      0.485592          0.940077         0.991774        0.965234
# 6      0.466986          0.941508         0.978211        0.959509
# 15     0.491440          0.941939         0.985919        0.963427
# 12     0.462630          0.941479         0.976506        0.958673
# 25     0.481320          0.942198         0.980953        0.961185
# 9      0.471462          0.942669         0.974876        0.958502
# 0      0.467949          0.942765         0.972949        0.957619
# 3      0.475666          0.943292         0.973912        0.958358
# 24     0.450064          0.943162         0.962944        0.952950
# 2      0.465281          0.943530         0.968354        0.955781
# 10     0.428256          0.945784         0.938635        0.942196
# 18     0.457014          0.947834         0.945305        0.946568
# 23     0.433290          0.950925         0.917661        0.933997

# %%
#df_met.to_csv('../col_wise_res/col_wise_1_4high_v1.csv',index=False)

# %%
import old

# %%
precision, recall, fscore, support = score(ytrain, tr_pred)
accuracy = accuracy_score(ytrain,tr_pred)
print('Accuracy: {}'.format(accuracy))

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
#print('support: {}'.format(support))

# %%
precision, recall, fscore, support = score(yvalid, test_pred)
accuracy = accuracy_score(yvalid,test_pred)
print('Accuracy: {}'.format(accuracy))

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
#print('support: {}'.format(support))

# %%
sub_data= {'employee_id':xtestproc['employee_id'],'is_promoted':sub_pred}

# %%
res = pd.DataFrame(sub_data)

# %%
res.to_csv("../results/pred3normal_nn.csv",index=False)

# %%
import stop

# %%
xtrain.isnull().sum().sum()

# %%
#rf = RandomForestClassifier(n_estimators = 20, random_state = 0,max_depth=None,min_samples_split=4)

# %%
#rf = DecisionTreeClassifier(criterion = "gini", max_depth=None,min_samples_split=4,random_state = 0)

# %%
rf = svm.SVC(kernel='linear', C=500, gamma=0.001)

# %%
rf.fit(xtrain,ytrain)

# %%
tr_pred = rf.predict(xtrain)

# %%
valid_pred = rf.predict(xvalid)

# %%
precision, recall, fscore, support = score(ytrain, tr_pred)
accuracy = accuracy_score(ytrain,tr_pred)
print('Accuracy: {}'.format(accuracy))

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
#print('support: {}'.format(support))

# %%
precision, recall, fscore, support = score(yvalid, valid_pred)
accuracy = accuracy_score(yvalid,valid_pred)
print('Accuracy: {}'.format(accuracy))

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
#print('support: {}'.format(support))

# %%
tr_data['is_promoted'].value_counts()

# %%
tr_data['department'].unique()

# %%
ts_data.shape

# %%
l1=ts_data['employee_id'].values
l2=tr_data['employee_id'].values
common=np.intersect1d(l1,l2)

# %%
common

# %%
np.sort(l1)

# %%
np.sort(l2)
